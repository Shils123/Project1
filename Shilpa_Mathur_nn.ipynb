# %% [markdown]
# <a href="https://colab.research.google.com/github/Shils123/Project1/blob/main/Shilpa_Mathur_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset

data_dir_train = pathlib.Path("/content/gdrive/MyDrive/Melanoma/Train")
data_dir_test = pathlib.Path('/content/gdrive/MyDrive/Melanoma/Test')
print(pathlib.Path.cwd()) 
path = pathlib.Path.cwd()
p = pathlib.Path('/content/gdrive/MyDrive/Melanoma')
for f in p.iterdir():
    print(f)
# Out:
# /content
# /content/gdrive/MyDrive/Melanoma/Test
# /content/gdrive/MyDrive/Melanoma/Train
# /content/gdrive/MyDrive/Melanoma/output

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, 
    image_size=(img_height, img_width),
    batch_size=batch_size,
    seed =123,
    subset= 'training',
    validation_split= 0.2)

print(type(train_ds))

#train_ds = tf.keras.utils.to_categorical(y_train, num_classes)
# The data, split between train and test sets:
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.
# <class 'tensorflow.python.data.ops.dataset_ops.BatchDataset'>

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
#val_ds = ##todo
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, 
    image_size=(img_height, img_width),
    batch_size=batch_size,
    seed =123,
    subset= 'validation',
    validation_split= 0.2)

print(type(val_ds))
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.
# <class 'tensorflow.python.data.ops.dataset_ops.BatchDataset'>

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)
### your code goes here, you can use training or validation data to visualize

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 64)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 64)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 529s 2s/step - loss: 2.0627 - accuracy: 0.1864 - val_loss: 2.0399 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 4s 79ms/step - loss: 2.0269 - accuracy: 0.1775 - val_loss: 2.0296 - val_accuracy: 0.1924
# Epoch 3/20
# 56/56 [==============================] - 4s 77ms/step - loss: 2.0257 - accuracy: 0.1953 - val_loss: 2.0139 - val_accuracy: 0.2416
# Epoch 4/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.9868 - accuracy: 0.2483 - val_loss: 1.9618 - val_accuracy: 0.2528
# Epoch 5/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9242 - accuracy: 0.2734 - val_loss: 1.6892 - val_accuracy: 0.3915
# Epoch 6/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.8170 - accuracy: 0.3231 - val_loss: 1.8035 - val_accuracy: 0.3311
# Epoch 7/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.6713 - accuracy: 0.4023 - val_loss: 1.5361 - val_accuracy: 0.4631
# Epoch 8/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.5584 - accuracy: 0.4436 - val_loss: 1.5273 - val_accuracy: 0.4564
# Epoch 9/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.5024 - accuracy: 0.4626 - val_loss: 1.4738 - val_accuracy: 0.4899
# Epoch 10/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.5390 - accuracy: 0.4593 - val_loss: 1.4429 - val_accuracy: 0.4832
# Epoch 11/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.4685 - accuracy: 0.4632 - val_loss: 1.6445 - val_accuracy: 0.4049
# Epoch 12/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.4469 - accuracy: 0.4939 - val_loss: 1.4843 - val_accuracy: 0.4944
# Epoch 13/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.3851 - accuracy: 0.5140 - val_loss: 1.4933 - val_accuracy: 0.4676
# Epoch 14/20
# 56/56 [==============================] - 4s 78ms/step - loss: 1.3807 - accuracy: 0.5229 - val_loss: 1.3903 - val_accuracy: 0.5145
# Epoch 15/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.2903 - accuracy: 0.5385 - val_loss: 1.4068 - val_accuracy: 0.5168
# Epoch 16/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.2809 - accuracy: 0.5458 - val_loss: 1.4933 - val_accuracy: 0.4877
# Epoch 17/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.1943 - accuracy: 0.5804 - val_loss: 1.5538 - val_accuracy: 0.4989
# Epoch 18/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.1884 - accuracy: 0.5753 - val_loss: 1.3900 - val_accuracy: 0.5056
# Epoch 19/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.1520 - accuracy: 0.5960 - val_loss: 1.7608 - val_accuracy: 0.4541
# Epoch 20/20
# 56/56 [==============================] - 4s 77ms/step - loss: 1.0940 - accuracy: 0.6021 - val_loss: 1.6319 - val_accuracy: 0.4653

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# [link text](https://)#### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here
#
# # Model starts to overfit after 15  epoch
# #Training accuracy is just 50% due to less data available for training

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here

from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - 8s 110ms/step - loss: 2.0668 - accuracy: 0.1920 - val_loss: 2.0358 - val_accuracy: 0.2058
# Epoch 2/30
# 56/56 [==============================] - 6s 105ms/step - loss: 2.0050 - accuracy: 0.2294 - val_loss: 1.9382 - val_accuracy: 0.2595
# Epoch 3/30
# 56/56 [==============================] - 6s 106ms/step - loss: 1.8983 - accuracy: 0.2863 - val_loss: 1.8520 - val_accuracy: 0.3020
# Epoch 4/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.8674 - accuracy: 0.2874 - val_loss: 1.7205 - val_accuracy: 0.3714
# Epoch 5/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.8292 - accuracy: 0.3237 - val_loss: 1.8041 - val_accuracy: 0.3177
# Epoch 6/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.8249 - accuracy: 0.3125 - val_loss: 1.6966 - val_accuracy: 0.3624
# Epoch 7/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.6803 - accuracy: 0.3789 - val_loss: 1.5878 - val_accuracy: 0.4206
# Epoch 8/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.6362 - accuracy: 0.4023 - val_loss: 1.6246 - val_accuracy: 0.4340
# Epoch 9/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.6150 - accuracy: 0.4258 - val_loss: 1.9672 - val_accuracy: 0.3199
# Epoch 10/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.6460 - accuracy: 0.3996 - val_loss: 1.5380 - val_accuracy: 0.4362
# Epoch 11/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.6265 - accuracy: 0.4096 - val_loss: 1.5674 - val_accuracy: 0.4720
# Epoch 12/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.5121 - accuracy: 0.4581 - val_loss: 1.5161 - val_accuracy: 0.4877
# Epoch 13/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.5176 - accuracy: 0.4715 - val_loss: 1.5399 - val_accuracy: 0.4541
# Epoch 14/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.4825 - accuracy: 0.4838 - val_loss: 1.4833 - val_accuracy: 0.4989
# Epoch 15/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.4658 - accuracy: 0.4833 - val_loss: 1.4760 - val_accuracy: 0.4922
# Epoch 16/30
# 56/56 [==============================] - 6s 106ms/step - loss: 1.4766 - accuracy: 0.4833 - val_loss: 1.5157 - val_accuracy: 0.4720
# Epoch 17/30
# 56/56 [==============================] - 7s 117ms/step - loss: 1.4207 - accuracy: 0.5006 - val_loss: 1.5122 - val_accuracy: 0.4653
# Epoch 18/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.4414 - accuracy: 0.4872 - val_loss: 1.4530 - val_accuracy: 0.5034
# Epoch 19/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.4615 - accuracy: 0.4911 - val_loss: 1.4571 - val_accuracy: 0.4832
# Epoch 20/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.4095 - accuracy: 0.5017 - val_loss: 1.5368 - val_accuracy: 0.4855
# Epoch 21/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.3958 - accuracy: 0.4950 - val_loss: 1.4258 - val_accuracy: 0.5190
# Epoch 22/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.3589 - accuracy: 0.5212 - val_loss: 1.4361 - val_accuracy: 0.4899
# Epoch 23/30
# 56/56 [==============================] - 6s 104ms/step - loss: 1.3373 - accuracy: 0.5279 - val_loss: 1.3626 - val_accuracy: 0.5145
# Epoch 24/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.3462 - accuracy: 0.5218 - val_loss: 1.4019 - val_accuracy: 0.4966
# Epoch 25/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.3081 - accuracy: 0.5441 - val_loss: 1.3843 - val_accuracy: 0.5190
# Epoch 26/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.3212 - accuracy: 0.5296 - val_loss: 1.3290 - val_accuracy: 0.5436
# Epoch 27/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.3084 - accuracy: 0.5374 - val_loss: 1.4152 - val_accuracy: 0.4989
# Epoch 28/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.2751 - accuracy: 0.5452 - val_loss: 1.3975 - val_accuracy: 0.5235
# Epoch 29/30
# 56/56 [==============================] - 6s 105ms/step - loss: 1.2686 - accuracy: 0.5564 - val_loss: 1.3254 - val_accuracy: 0.5123
# Epoch 30/30
# 56/56 [==============================] - 6s 106ms/step - loss: 1.2584 - accuracy: 0.5597 - val_loss: 1.3394 - val_accuracy: 0.5257

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# # There is no improvment in model accuracy

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
##
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 1     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 2     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 3     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 4     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2235  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2236  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2237  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2238  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 1     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 2     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 3     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 4     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2235  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2236  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2237  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2238  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples? **seborrheic keratosis**
# #### - Which classes dominate the data in terms proportionate number of samples? **pigmented benign keratosis**

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.1)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/MyDrive/Melanoma/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i,save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F367E87EE90>: 100%|██████████| 500/500 [00:20<00:00, 24.07 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F367E97EC10>: 100%|██████████| 500/500 [00:21<00:00, 23.17 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F367E97EB90>: 100%|██████████| 500/500 [00:21<00:00, 23.01 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F367E906FD0>: 100%|██████████| 500/500 [01:36<00:00,  5.21 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=576x768 at 0x7F367E97EB10>: 100%|██████████| 500/500 [01:18<00:00,  6.34 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F369623F290>: 100%|██████████| 500/500 [00:17<00:00, 28.06 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F37028214D0>: 100%|██████████| 500/500 [00:42<00:00, 11.84 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F367EE06050>: 100%|██████████| 500/500 [00:20<00:00, 24.91 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Melanoma/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F36FB62C450>: 100%|██████████| 500/500 [00:18<00:00, 27.46 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train1 = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train1)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
# Import necessary packages
#import os
#from glob import glob
#path_list = [x for x in glob(os.path.join(data_dir_train1, '*', '*.jpg'))]
#path_list
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
new_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
new_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 1     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 2     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 3     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# 4     /content/gdrive/MyDrive/Melanoma/Train/actinic...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2235  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2236  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2237  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
# 2238  /content/gdrive/MyDrive/Melanoma/Train/vascula...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
#lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
#lesion_list_new

# %%
#dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
#df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
#new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
data_dir_train1 = pathlib.Path("/content/gdrive/MyDrive/Melanoma/Train")
image_count_train1 = len(list(data_dir_train1.glob('*/*.jpg')))
print(image_count_train1)
# Out:
# 2239

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
#data_dir_train="path to directory with training data + data created using augmentor"
import tensorflow as tf

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  image_size=(img_height, img_width),
  subset = 'training',## Todo choose the correct parameter value, so that only training data is refered to,,
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train1,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ 
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
## Your code goes here, use 30 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 169/169 [==============================] - 45s 255ms/step - loss: 2.1689 - accuracy: 0.1530 - val_loss: 1.9839 - val_accuracy: 0.2368
# Epoch 2/30
# 169/169 [==============================] - 35s 201ms/step - loss: 1.9923 - accuracy: 0.2461 - val_loss: 1.7236 - val_accuracy: 0.3645
# Epoch 3/30
# 169/169 [==============================] - 34s 195ms/step - loss: 1.6314 - accuracy: 0.3863 - val_loss: 1.6490 - val_accuracy: 0.3942
# Epoch 4/30
# 169/169 [==============================] - 34s 195ms/step - loss: 1.4957 - accuracy: 0.4342 - val_loss: 1.4258 - val_accuracy: 0.4603
# Epoch 5/30
# 169/169 [==============================] - 35s 203ms/step - loss: 1.4661 - accuracy: 0.4542 - val_loss: 1.5736 - val_accuracy: 0.4195
# Epoch 6/30
# 169/169 [==============================] - 34s 196ms/step - loss: 1.4415 - accuracy: 0.4616 - val_loss: 1.4186 - val_accuracy: 0.4714
# Epoch 7/30
# 169/169 [==============================] - 34s 196ms/step - loss: 1.3104 - accuracy: 0.5126 - val_loss: 1.3062 - val_accuracy: 0.5197
# Epoch 8/30
# 169/169 [==============================] - 34s 198ms/step - loss: 1.2715 - accuracy: 0.5241 - val_loss: 1.3581 - val_accuracy: 0.5026
# Epoch 9/30
# 169/169 [==============================] - 34s 195ms/step - loss: 1.1775 - accuracy: 0.5519 - val_loss: 1.2401 - val_accuracy: 0.5316
# Epoch 10/30
# 169/169 [==============================] - 35s 203ms/step - loss: 1.1238 - accuracy: 0.5868 - val_loss: 1.1792 - val_accuracy: 0.5657
# Epoch 11/30
# 169/169 [==============================] - 34s 194ms/step - loss: 1.0612 - accuracy: 0.6085 - val_loss: 1.4321 - val_accuracy: 0.4981
# Epoch 12/30
# 169/169 [==============================] - 34s 196ms/step - loss: 0.9626 - accuracy: 0.6452 - val_loss: 1.1021 - val_accuracy: 0.6206
# Epoch 13/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.9137 - accuracy: 0.6638 - val_loss: 1.1527 - val_accuracy: 0.5976
# Epoch 14/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.8315 - accuracy: 0.6912 - val_loss: 0.9847 - val_accuracy: 0.6533
# Epoch 15/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.7886 - accuracy: 0.7066 - val_loss: 1.0289 - val_accuracy: 0.6392
# Epoch 16/30
# 169/169 [==============================] - 35s 203ms/step - loss: 0.7432 - accuracy: 0.7248 - val_loss: 1.0206 - val_accuracy: 0.6867
# Epoch 17/30
# 169/169 [==============================] - 34s 194ms/step - loss: 0.6897 - accuracy: 0.7457 - val_loss: 1.0644 - val_accuracy: 0.6444
# Epoch 18/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.6280 - accuracy: 0.7671 - val_loss: 1.0198 - val_accuracy: 0.6674
# Epoch 19/30
# 169/169 [==============================] - 34s 196ms/step - loss: 0.6434 - accuracy: 0.7654 - val_loss: 1.1083 - val_accuracy: 0.6503
# Epoch 20/30
# 169/169 [==============================] - 34s 194ms/step - loss: 0.5724 - accuracy: 0.7888 - val_loss: 1.0168 - val_accuracy: 0.6986
# Epoch 21/30
# 169/169 [==============================] - 35s 202ms/step - loss: 0.5307 - accuracy: 0.8121 - val_loss: 1.1124 - val_accuracy: 0.6659
# Epoch 22/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.5170 - accuracy: 0.8080 - val_loss: 1.1472 - val_accuracy: 0.6837
# Epoch 23/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.4952 - accuracy: 0.8175 - val_loss: 0.9931 - val_accuracy: 0.7313
# Epoch 24/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.4522 - accuracy: 0.8351 - val_loss: 1.0526 - val_accuracy: 0.7209
# Epoch 25/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.4878 - accuracy: 0.8283 - val_loss: 1.0281 - val_accuracy: 0.7290
# Epoch 26/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.4097 - accuracy: 0.8552 - val_loss: 0.9896 - val_accuracy: 0.7298
# Epoch 27/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.4187 - accuracy: 0.8507 - val_loss: 1.0845 - val_accuracy: 0.7231
# Epoch 28/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.3848 - accuracy: 0.8602 - val_loss: 1.0468 - val_accuracy: 0.7416
# Epoch 29/30
# 169/169 [==============================] - 34s 194ms/step - loss: 0.4529 - accuracy: 0.8442 - val_loss: 1.1258 - val_accuracy: 0.7149
# Epoch 30/30
# 169/169 [==============================] - 34s 194ms/step - loss: 0.3434 - accuracy: 0.8746 - val_loss: 1.0341 - val_accuracy: 0.7327

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %%
# Accuracy of data has increased 
# Model is overfitting
